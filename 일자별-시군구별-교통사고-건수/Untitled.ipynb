# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
# %matplotlib inline 

import matplotlib as mpl 
plt.rcParams['font.family'] = 'Malgun Gothic'

import seaborn as sns

# %%
data2016 = pd.read_csv('dataset/교통사고2016.csv', encoding = 'euc-kr')
data2017 = pd.read_csv('dataset/교통사고2017.csv', encoding = 'euc-kr')
data2018 = pd.read_csv('dataset/교통사고2018.csv', encoding = 'euc-kr')
data2019 = pd.read_csv('dataset/교통사고2019.csv', encoding = 'euc-kr')
data2020 = pd.read_csv('dataset/교통사고2020.csv', encoding = 'euc-kr')

# %%
data2016['연'] = 2016
data2017['연'] = 2017
data2018['연'] = 2018
data2019['연'] = 2019
data2020['연'] = 2020

# %%
data2016['월'] == 1
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 61426    False
# 61427    False
# 61428    False
# 61429    False
# 61430    False
# Name: 월, Length: 61431, dtype: bool

# %%
data2016[(data2016['월'] == 1) & (data2016['시군구'] == '종로구')]
# Out:
#       월   일  시도  시군구  사고건수  사망자수  중상자수  경상자수  부상신고자수     연
# 0     1   1  서울  종로구     1     0     2     2       0  2016
# 169   1   2  서울  종로구     2     0     1     2       0  2016
# 330   1   3  서울  종로구     2     0     2     1       0  2016
# 482   1   4  서울  종로구     3     0     2     1       0  2016
# 639   1   5  서울  종로구     4     0     2     2       2  2016
# 803   1   6  서울  종로구     7     0     0     7       1  2016
# 950   1   7  서울  종로구     4     0     1     6       0  2016
# 1114  1   8  서울  종로구     2     0     3     0       1  2016
# 1275  1   9  서울  종로구     5     0     1     6       0  2016
# 1435  1  10  서울  종로구     2     0     1     1       0  2016
# 1580  1  11  서울  종로구     5     0     1     3       2  2016
# 1743  1  12  서울  종로구     5     0     3     4       1  2016
# 2071  1  14  서울  종로구     2     0     1     3       0  2016
# 2234  1  15  서울  종로구     3     0     1     2       0  2016
# 2394  1  16  서울  종로구     7     0     4     6       1  2016
# ...
